# %% [markdown]
# # Lab 9: Monte Carlo Tree Search in Games

# %% [markdown]
# ## Setup (run & skip)
#
# We will use [OpenSpiel](https://github.com/deepmind/open_spiel) again.

# %%
# *Important*:
# This takes a while: ~10min, so it's better to do before the lab starts.
#
# Currently, it prints some errors about dependency versions, but those 
# packages are not relevant to what we will use in the lab, so it is ok.
# !pip install open_spiel tqdm

# Let's make some imports
from typing import Callable, Dict, List, Tuple, Union
import functools
import itertools

import numpy as np
import pyspiel
import tqdm
import copy

from collections import defaultdict
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting open_spiel
#   Downloading open_spiel-1.2.tar.gz (3.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 11.7 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tqdm in /usr/lib/python3.11/site-packages (4.65.0)
# Requirement already satisfied: pip>=20.0.2 in /usr/lib/python3.11/site-packages (from open_spiel) (23.1.2)
# Requirement already satisfied: attrs>=19.3.0 in /usr/lib/python3.11/site-packages (from open_spiel) (22.2.0)
# Collecting absl-py>=0.10.0 (from open_spiel)
#   Downloading absl_py-1.4.0-py3-none-any.whl (126 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.5/126.5 kB 17.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.21.5 in /usr/lib/python3.11/site-packages (from open_spiel) (1.24.3)
# Collecting scipy>=1.7.3 (from open_spiel)
#   Downloading scipy-1.10.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.1/34.1 MB 12.2 MB/s eta 0:00:0000:0100:01
# Building wheels for collected packages: open_spiel
#   Building wheel for open_spiel (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [871 lines of output]
#       running bdist_wheel
#       running build
#       running build_py
#       creating build
#       creating build/lib.linux-x86_64-cpython-311
#       creating build/lib.linux-x86_64-cpython-311/open_spiel
#       copying open_spiel/__init__.py -> build/lib.linux-x86_64-cpython-311/open_spiel
#       creating build/lib.linux-x86_64-cpython-311/open_spiel/python
#       copying open_spiel/python/test_utils.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python
#       copying open_spiel/python/simple_nets.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python
#       copying open_spiel/python/rl_tools.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python
#       copying open_spiel/python/rl_environment.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python
#       copying open_spiel/python/rl_agent_policy.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python
#       copying open_spiel/python/rl_agent.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python
#       copying open_spiel/python/policy.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python
#       copying open_spiel/python/observation.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python
#       copying open_spiel/python/__init__.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python
#       creating build/lib.linux-x86_64-cpython-311/open_spiel/integration_tests
#       copying open_spiel/integration_tests/playthrough_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/integration_tests
#       copying open_spiel/integration_tests/api_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/integration_tests
#       copying open_spiel/integration_tests/__init__.py -> build/lib.linux-x86_64-cpython-311/open_spiel/integration_tests
#       creating build/lib.linux-x86_64-cpython-311/open_spiel/python/visualizations
#       copying open_spiel/python/visualizations/treeviz.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/visualizations
#       copying open_spiel/python/visualizations/__init__.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/visualizations
#       creating build/lib.linux-x86_64-cpython-311/open_spiel/python/utils
#       copying open_spiel/python/utils/training.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/utils
#       copying open_spiel/python/utils/stats.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/utils
#       copying open_spiel/python/utils/spawn_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/utils
#       copying open_spiel/python/utils/spawn.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/utils
#       copying open_spiel/python/utils/shared_value.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/utils
#       copying open_spiel/python/utils/reservoir_buffer.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/utils
#       copying open_spiel/python/utils/replay_buffer_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/utils
#       copying open_spiel/python/utils/replay_buffer.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/utils
#       copying open_spiel/python/utils/metrics_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/utils
#       copying open_spiel/python/utils/metrics.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/utils
#       copying open_spiel/python/utils/lru_cache_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/utils
#       copying open_spiel/python/utils/lru_cache.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/utils
#       copying open_spiel/python/utils/gfile.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/utils
#       copying open_spiel/python/utils/file_utils.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/utils
#       copying open_spiel/python/utils/file_logger_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/utils
#       copying open_spiel/python/utils/file_logger.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/utils
#       copying open_spiel/python/utils/data_logger.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/utils
#       copying open_spiel/python/utils/app.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/utils
#       copying open_spiel/python/utils/__init__.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/utils
#       creating build/lib.linux-x86_64-cpython-311/open_spiel/python/tests
#       copying open_spiel/python/tests/tensor_game_utils_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/tests
#       copying open_spiel/python/tests/sampled_stochastic_games_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/tests
#       copying open_spiel/python/tests/rl_environment_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/tests
#       copying open_spiel/python/tests/pyspiel_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/tests
#       copying open_spiel/python/tests/policy_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/tests
#       copying open_spiel/python/tests/observation_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/tests
#       copying open_spiel/python/tests/nfg_writer_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/tests
#       copying open_spiel/python/tests/nfg_game_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/tests
#       copying open_spiel/python/tests/matrix_game_utils_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/tests
#       copying open_spiel/python/tests/higc_referee_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/tests
#       copying open_spiel/python/tests/games_sim_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/tests
#       copying open_spiel/python/tests/games_euchre_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/tests
#       copying open_spiel/python/tests/games_bridge_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/tests
#       copying open_spiel/python/tests/game_transforms_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/tests
#       copying open_spiel/python/tests/bot_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/tests
#       copying open_spiel/python/tests/__init__.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/tests
#       creating build/lib.linux-x86_64-cpython-311/open_spiel/python/pytorch
#       copying open_spiel/python/pytorch/rcfr_pytorch_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/pytorch
#       copying open_spiel/python/pytorch/rcfr.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/pytorch
#       copying open_spiel/python/pytorch/policy_gradient_pytorch_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/pytorch
#       copying open_spiel/python/pytorch/policy_gradient.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/pytorch
#       copying open_spiel/python/pytorch/nfsp_pytorch_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/pytorch
#       copying open_spiel/python/pytorch/nfsp.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/pytorch
#       copying open_spiel/python/pytorch/neurd_pytorch_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/pytorch
#       copying open_spiel/python/pytorch/neurd.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/pytorch
#       copying open_spiel/python/pytorch/eva_pytorch_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/pytorch
#       copying open_spiel/python/pytorch/eva.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/pytorch
#       copying open_spiel/python/pytorch/dqn_pytorch_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/pytorch
#       copying open_spiel/python/pytorch/dqn.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/pytorch
#       copying open_spiel/python/pytorch/deep_cfr_pytorch_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/pytorch
#       copying open_spiel/python/pytorch/deep_cfr.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/pytorch
#       copying open_spiel/python/pytorch/__init__.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/pytorch
#       creating build/lib.linux-x86_64-cpython-311/open_spiel/python/mfg
#       copying open_spiel/python/mfg/value.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/mfg
#       copying open_spiel/python/mfg/utils.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/mfg
#       copying open_spiel/python/mfg/tabular_distribution.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/mfg
#       copying open_spiel/python/mfg/distribution.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/mfg
#       copying open_spiel/python/mfg/__init__.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/mfg
#       creating build/lib.linux-x86_64-cpython-311/open_spiel/python/jax
#       copying open_spiel/python/jax/policy_gradient_jax_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/jax
#       copying open_spiel/python/jax/policy_gradient.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/jax
#       copying open_spiel/python/jax/nfsp_jax_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/jax
#       copying open_spiel/python/jax/nfsp.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/jax
#       copying open_spiel/python/jax/dqn_jax_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/jax
#       copying open_spiel/python/jax/dqn.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/jax
#       copying open_spiel/python/jax/deep_cfr_jax_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/jax
#       copying open_spiel/python/jax/deep_cfr.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/jax
#       copying open_spiel/python/jax/boltzmann_dqn_jax_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/jax
#       copying open_spiel/python/jax/boltzmann_dqn.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/jax
#       copying open_spiel/python/jax/__init__.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/jax
#       creating build/lib.linux-x86_64-cpython-311/open_spiel/python/games
#       copying open_spiel/python/games/tic_tac_toe_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/games
#       copying open_spiel/python/games/tic_tac_toe.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/games
#       copying open_spiel/python/games/kuhn_poker_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/games
#       copying open_spiel/python/games/kuhn_poker.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/games
#       copying open_spiel/python/games/iterated_prisoners_dilemma_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/games
#       copying open_spiel/python/games/iterated_prisoners_dilemma.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/games
#       copying open_spiel/python/games/dynamic_routing_utils_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/games
#       copying open_spiel/python/games/dynamic_routing_utils.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/games
#       copying open_spiel/python/games/dynamic_routing_to_mean_field_game_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/games
#       copying open_spiel/python/games/dynamic_routing_to_mean_field_game.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/games
#       copying open_spiel/python/games/dynamic_routing_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/games
#       copying open_spiel/python/games/dynamic_routing_data.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/games
#       copying open_spiel/python/games/dynamic_routing.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/games
#       copying open_spiel/python/games/data_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/games
#       copying open_spiel/python/games/data.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/games
#       copying open_spiel/python/games/__init__.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/games
#       creating build/lib.linux-x86_64-cpython-311/open_spiel/python/examples
#       copying open_spiel/python/examples/value_iteration.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/examples
#       copying open_spiel/python/examples/uniform_policy_exploitability.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/examples
#       copying open_spiel/python/examples/treeviz_example.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/examples
#       copying open_spiel/python/examples/tic_tac_toe_qlearner.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/examples
#       copying open_spiel/python/examples/tic_tac_toe_dqn_vs_tabular.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/examples
#       copying open_spiel/python/examples/tic_tac_toe_alpha_zero.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/examples
#       copying open_spiel/python/examples/skat_dqn.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/examples
#       copying open_spiel/python/examples/single_agent_cliff_walking.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/examples
#       copying open_spiel/python/examples/single_agent_catch.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/examples
#       copying open_spiel/python/examples/rl_response.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/examples
#       copying open_spiel/python/examples/rl_main_loop.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/examples
#       copying open_spiel/python/examples/rl_example.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/examples
#       copying open_spiel/python/examples/response_graph_ucb_sample_complexity.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/examples
#       copying open_spiel/python/examples/response_graph_ucb_2x2_game.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/examples
#       copying open_spiel/python/examples/rcfr_example.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/examples
#       copying open_spiel/python/examples/query_example.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/examples
#       copying open_spiel/python/examples/psro_v2_example.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/examples
#       copying open_spiel/python/examples/policy_aggregator_example.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/examples
#       copying open_spiel/python/examples/poker_fcpa_example.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/examples
#       copying open_spiel/python/examples/playthrough.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/examples
#       copying open_spiel/python/examples/play_tarok_game.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/examples
#       copying open_spiel/python/examples/play_scenarios.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/examples
#       copying open_spiel/python/examples/nfg_writer_example.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/examples
#       copying open_spiel/python/examples/neurd_example.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/examples
#       copying open_spiel/python/examples/nego_nbs_example.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/examples
#       copying open_spiel/python/examples/mmd_nash_example.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/examples
#       copying open_spiel/python/examples/mmd_matrix_example.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/examples
#       copying open_spiel/python/examples/mmd_example.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/examples
#       copying open_spiel/python/examples/mcts.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/examples
#       copying open_spiel/python/examples/mccfr_example.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/examples
#       copying open_spiel/python/examples/mccfr_cpp_example.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/examples
#       copying open_spiel/python/examples/matrix_nash_example.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/examples
#       copying open_spiel/python/examples/matrix_game_example.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/examples
#       copying open_spiel/python/examples/marl_nashq_example.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/examples
#       copying open_spiel/python/examples/lp_solve_example.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/examples
#       copying open_spiel/python/examples/lewis_signaling_qlearner.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/examples
#       copying open_spiel/python/examples/lewis_signaling_dqn.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/examples
#       copying open_spiel/python/examples/leduc_nfsp.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/examples
#       copying open_spiel/python/examples/kuhn_policy_gradient.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/examples
#       copying open_spiel/python/examples/kuhn_poker_cfr.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/examples
#       copying open_spiel/python/examples/kuhn_nfsp.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/examples
#       copying open_spiel/python/examples/jpsro.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/examples
#       copying open_spiel/python/examples/is_mcts_exploitability.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/examples
#       copying open_spiel/python/examples/independent_tabular_qlearning.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/examples
#       copying open_spiel/python/examples/hearts_supervised_learning.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/examples
#       copying open_spiel/python/examples/get_all_states.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/examples
#       copying open_spiel/python/examples/gambit_example.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/examples
#       copying open_spiel/python/examples/fictitious_play_example.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/examples
#       copying open_spiel/python/examples/exploitability_descent.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/examples
#       copying open_spiel/python/examples/example.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/examples
#       copying open_spiel/python/examples/eva.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/examples
#       copying open_spiel/python/examples/discounted_cfr.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/examples
#       copying open_spiel/python/examples/deep_cfr_tf2.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/examples
#       copying open_spiel/python/examples/deep_cfr_pytorch.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/examples
#       copying open_spiel/python/examples/deep_cfr_jax.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/examples
#       copying open_spiel/python/examples/deep_cfr.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/examples
#       copying open_spiel/python/examples/cfr_example.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/examples
#       copying open_spiel/python/examples/cfr_cpp_example.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/examples
#       copying open_spiel/python/examples/catch_pytorch_policy_gradient.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/examples
#       copying open_spiel/python/examples/catch_jax_policy_gradient.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/examples
#       copying open_spiel/python/examples/bridge_wb5.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/examples
#       copying open_spiel/python/examples/bridge_uncontested_bidding_bluechip.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/examples
#       copying open_spiel/python/examples/bridge_supervised_learning.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/examples
#       copying open_spiel/python/examples/breakthrough_dqn.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/examples
#       copying open_spiel/python/examples/benchmark_games.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/examples
#       copying open_spiel/python/examples/alpha_zero.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/examples
#       copying open_spiel/python/examples/__init__.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/examples
#       creating build/lib.linux-x86_64-cpython-311/open_spiel/python/environments
#       copying open_spiel/python/environments/cliff_walking_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/environments
#       copying open_spiel/python/environments/cliff_walking.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/environments
#       copying open_spiel/python/environments/catch_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/environments
#       copying open_spiel/python/environments/catch.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/environments
#       copying open_spiel/python/environments/__init__.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/environments
#       creating build/lib.linux-x86_64-cpython-311/open_spiel/python/egt
#       copying open_spiel/python/egt/visualization_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/egt
#       copying open_spiel/python/egt/visualization.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/egt
#       copying open_spiel/python/egt/utils_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/egt
#       copying open_spiel/python/egt/utils.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/egt
#       copying open_spiel/python/egt/heuristic_payoff_table_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/egt
#       copying open_spiel/python/egt/heuristic_payoff_table.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/egt
#       copying open_spiel/python/egt/dynamics_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/egt
#       copying open_spiel/python/egt/dynamics.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/egt
#       copying open_spiel/python/egt/alpharank_visualizer_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/egt
#       copying open_spiel/python/egt/alpharank_visualizer.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/egt
#       copying open_spiel/python/egt/alpharank_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/egt
#       copying open_spiel/python/egt/alpharank.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/egt
#       copying open_spiel/python/egt/__init__.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/egt
#       creating build/lib.linux-x86_64-cpython-311/open_spiel/python/bots
#       copying open_spiel/python/bots/uniform_random_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/bots
#       copying open_spiel/python/bots/uniform_random.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/bots
#       copying open_spiel/python/bots/scenarios.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/bots
#       copying open_spiel/python/bots/policy.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/bots
#       copying open_spiel/python/bots/is_mcts_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/bots
#       copying open_spiel/python/bots/human.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/bots
#       copying open_spiel/python/bots/higc_random_bot_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/bots
#       copying open_spiel/python/bots/gtp.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/bots
#       copying open_spiel/python/bots/bluechip_bridge_uncontested_bidding_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/bots
#       copying open_spiel/python/bots/bluechip_bridge_uncontested_bidding.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/bots
#       copying open_spiel/python/bots/bluechip_bridge_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/bots
#       copying open_spiel/python/bots/bluechip_bridge.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/bots
#       copying open_spiel/python/bots/__init__.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/bots
#       creating build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/wolf_phc_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/wolf_phc.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/value_iteration_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/value_iteration.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/tabular_qlearner_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/tabular_qlearner.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/tabular_multiagent_qlearner_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/tabular_multiagent_qlearner.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/stackelberg_lp_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/stackelberg_lp.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/sequence_form_utils_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/sequence_form_utils.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/sequence_form_lp_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/sequence_form_lp.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/sample_some_states_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/sample_some_states.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/response_graph_ucb_utils.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/response_graph_ucb_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/response_graph_ucb.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/rcfr_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/rcfr.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/random_agent_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/random_agent.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/projected_replicator_dynamics_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/projected_replicator_dynamics.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/policy_utils.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/policy_gradient_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/policy_gradient.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/policy_aggregator_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/policy_aggregator_joint_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/policy_aggregator_joint.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/policy_aggregator.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/outcome_sampling_mccfr_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/outcome_sampling_mccfr.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/noisy_policy_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/noisy_policy.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/nfsp_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/nfsp.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/neurd_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/neurd.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/nash_averaging_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/nash_averaging.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/mmd_dilated_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/mmd_dilated.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/minimax_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/minimax.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/mcts_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/mcts_agent_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/mcts_agent.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/mcts.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/mccfr.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/matrix_nash.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/masked_softmax_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/masked_softmax.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/lp_solver_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/lp_solver.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/jpsro_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/jpsro.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/get_all_states_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/get_all_states.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/generate_playthrough_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/generate_playthrough.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/gambit_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/gambit.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/fictitious_play_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/fictitious_play.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/external_sampling_mccfr_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/external_sampling_mccfr.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/exploitability_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/exploitability_descent_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/exploitability_descent.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/exploitability.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/expected_game_score_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/expected_game_score.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/evaluate_bots_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/evaluate_bots.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/eva_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/eva.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/dqn_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/dqn.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/double_oracle_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/double_oracle.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/discounted_cfr_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/discounted_cfr.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/deep_cfr_tf2_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/deep_cfr_tf2.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/deep_cfr_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/deep_cfr.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/cfr_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/cfr_br_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/cfr_br.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/cfr.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/boltzmann_tabular_qlearner_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/boltzmann_tabular_qlearner.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/best_response_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/best_response.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/adidas_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/adidas.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/action_value_vs_best_response_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/action_value_vs_best_response.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/action_value_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/action_value.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       copying open_spiel/python/algorithms/__init__.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms
#       creating build/lib.linux-x86_64-cpython-311/open_spiel/python/tests/mfg_implementation_test
#       copying open_spiel/python/tests/mfg_implementation_test/mfg_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/tests/mfg_implementation_test
#       copying open_spiel/python/tests/mfg_implementation_test/__init__.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/tests/mfg_implementation_test
#       creating build/lib.linux-x86_64-cpython-311/open_spiel/python/pytorch/losses
#       copying open_spiel/python/pytorch/losses/rl_losses_pytorch_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/pytorch/losses
#       copying open_spiel/python/pytorch/losses/rl_losses.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/pytorch/losses
#       copying open_spiel/python/pytorch/losses/__init__.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/pytorch/losses
#       creating build/lib.linux-x86_64-cpython-311/open_spiel/python/mfg/games
#       copying open_spiel/python/mfg/games/predator_prey_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/mfg/games
#       copying open_spiel/python/mfg/games/predator_prey.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/mfg/games
#       copying open_spiel/python/mfg/games/linear_quadratic_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/mfg/games
#       copying open_spiel/python/mfg/games/linear_quadratic_example.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/mfg/games
#       copying open_spiel/python/mfg/games/linear_quadratic.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/mfg/games
#       copying open_spiel/python/mfg/games/factory_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/mfg/games
#       copying open_spiel/python/mfg/games/factory.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/mfg/games
#       copying open_spiel/python/mfg/games/dynamic_routing_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/mfg/games
#       copying open_spiel/python/mfg/games/dynamic_routing.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/mfg/games
#       copying open_spiel/python/mfg/games/crowd_modelling_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/mfg/games
#       copying open_spiel/python/mfg/games/crowd_modelling_2d_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/mfg/games
#       copying open_spiel/python/mfg/games/crowd_modelling_2d.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/mfg/games
#       copying open_spiel/python/mfg/games/crowd_modelling.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/mfg/games
#       copying open_spiel/python/mfg/games/__init__.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/mfg/games
#       creating build/lib.linux-x86_64-cpython-311/open_spiel/python/mfg/algorithms
#       copying open_spiel/python/mfg/algorithms/softmax_policy_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/mfg/algorithms
#       copying open_spiel/python/mfg/algorithms/softmax_policy.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/mfg/algorithms
#       copying open_spiel/python/mfg/algorithms/policy_value_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/mfg/algorithms
#       copying open_spiel/python/mfg/algorithms/policy_value.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/mfg/algorithms
#       copying open_spiel/python/mfg/algorithms/nash_conv_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/mfg/algorithms
#       copying open_spiel/python/mfg/algorithms/nash_conv.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/mfg/algorithms
#       copying open_spiel/python/mfg/algorithms/munchausen_deep_mirror_descent_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/mfg/algorithms
#       copying open_spiel/python/mfg/algorithms/munchausen_deep_mirror_descent.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/mfg/algorithms
#       copying open_spiel/python/mfg/algorithms/mirror_descent_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/mfg/algorithms
#       copying open_spiel/python/mfg/algorithms/mirror_descent.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/mfg/algorithms
#       copying open_spiel/python/mfg/algorithms/greedy_policy_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/mfg/algorithms
#       copying open_spiel/python/mfg/algorithms/greedy_policy.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/mfg/algorithms
#       copying open_spiel/python/mfg/algorithms/fictitious_play_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/mfg/algorithms
#       copying open_spiel/python/mfg/algorithms/fictitious_play.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/mfg/algorithms
#       copying open_spiel/python/mfg/algorithms/distribution_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/mfg/algorithms
#       copying open_spiel/python/mfg/algorithms/distribution.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/mfg/algorithms
#       copying open_spiel/python/mfg/algorithms/best_response_value_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/mfg/algorithms
#       copying open_spiel/python/mfg/algorithms/best_response_value.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/mfg/algorithms
#       copying open_spiel/python/mfg/algorithms/benchmark.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/mfg/algorithms
#       copying open_spiel/python/mfg/algorithms/average_network_fictitious_play_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/mfg/algorithms
#       copying open_spiel/python/mfg/algorithms/average_network_fictitious_play.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/mfg/algorithms
#       copying open_spiel/python/mfg/algorithms/__init__.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/mfg/algorithms
#       creating build/lib.linux-x86_64-cpython-311/open_spiel/python/egt/examples
#       copying open_spiel/python/egt/examples/alpharank_example.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/egt/examples
#       copying open_spiel/python/egt/examples/__init__.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/egt/examples
#       creating build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms/psro_v2
#       copying open_spiel/python/algorithms/psro_v2/utils.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms/psro_v2
#       copying open_spiel/python/algorithms/psro_v2/strategy_selectors_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms/psro_v2
#       copying open_spiel/python/algorithms/psro_v2/strategy_selectors.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms/psro_v2
#       copying open_spiel/python/algorithms/psro_v2/rl_policy.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms/psro_v2
#       copying open_spiel/python/algorithms/psro_v2/rl_oracle.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms/psro_v2
#       copying open_spiel/python/algorithms/psro_v2/psro_v2.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms/psro_v2
#       copying open_spiel/python/algorithms/psro_v2/optimization_oracle.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms/psro_v2
#       copying open_spiel/python/algorithms/psro_v2/meta_strategies.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms/psro_v2
#       copying open_spiel/python/algorithms/psro_v2/best_response_oracle_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms/psro_v2
#       copying open_spiel/python/algorithms/psro_v2/best_response_oracle.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms/psro_v2
#       copying open_spiel/python/algorithms/psro_v2/abstract_meta_trainer.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms/psro_v2
#       copying open_spiel/python/algorithms/psro_v2/__init__.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms/psro_v2
#       creating build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms/losses
#       copying open_spiel/python/algorithms/losses/rl_losses_test.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms/losses
#       copying open_spiel/python/algorithms/losses/rl_losses.py -> build/lib.linux-x86_64-cpython-311/open_spiel/python/algorithms/losses
# ...
#         return (static_cast<uint8_t>(haystack) & static_cast<uint8_t>(needle)) ==
#                                      ~~~~~~~~  ^                      ~~~~~~
#       /tmp/pip-install-of161ct7/open-spiel_54b6d96738814245809e552fe7edf055/open_spiel/abseil-cpp/absl/strings/internal/str_format/extension.h:149:22: error: unknown type name 'uint8_t'
#                static_cast<uint8_t>(needle);
#                            ^
#       /tmp/pip-install-of161ct7/open-spiel_54b6d96738814245809e552fe7edf055/open_spiel/abseil-cpp/absl/strings/internal/str_format/extension.h:187:21: error: unknown type name 'uint8_t'
#         enum class Enum : uint8_t {
#                           ^
#       /tmp/pip-install-of161ct7/open-spiel_54b6d96738814245809e552fe7edf055/open_spiel/abseil-cpp/absl/strings/internal/str_format/extension.h:345:19: error: unknown type name 'uint64_t'
#             static_cast<uint64_t>(a) |
#                         ^
#       /tmp/pip-install-of161ct7/open-spiel_54b6d96738814245809e552fe7edf055/open_spiel/abseil-cpp/absl/strings/internal/str_format/extension.h:346:19: error: unknown type name 'uint64_t'
#             static_cast<uint64_t>(FormatConversionCharSetUnion(rest...)));
#                         ^
#       /tmp/pip-install-of161ct7/open-spiel_54b6d96738814245809e552fe7edf055/open_spiel/abseil-cpp/absl/strings/internal/str_format/extension.h:349:11: error: unknown type name 'uint64_t'
#       constexpr uint64_t FormatConversionCharToConvInt(FormatConversionChar c) {
#                 ^
#       /tmp/pip-install-of161ct7/open-spiel_54b6d96738814245809e552fe7edf055/open_spiel/abseil-cpp/absl/strings/internal/str_format/extension.h:350:10: error: use of undeclared identifier 'uint64_t'
#         return uint64_t{1} << (1 + static_cast<uint8_t>(c));
#                ^
#       /tmp/pip-install-of161ct7/open-spiel_54b6d96738814245809e552fe7edf055/open_spiel/abseil-cpp/absl/strings/internal/str_format/extension.h:350:18: error: expected ';' after return statement
#         return uint64_t{1} << (1 + static_cast<uint8_t>(c));
#                        ^
#                        ;
#       /tmp/pip-install-of161ct7/open-spiel_54b6d96738814245809e552fe7edf055/open_spiel/abseil-cpp/absl/strings/internal/str_format/extension.h:353:11: error: unknown type name 'uint64_t'
#       constexpr uint64_t FormatConversionCharToConvInt(char conv) {
#                 ^
#       /tmp/pip-install-of161ct7/open-spiel_54b6d96738814245809e552fe7edf055/open_spiel/abseil-cpp/absl/strings/internal/str_format/extension.h:366:35: error: no return statement in constexpr function
#       constexpr FormatConversionCharSet FormatConversionCharToConvValue(char conv) {
#                                         ^
#       /tmp/pip-install-of161ct7/open-spiel_54b6d96738814245809e552fe7edf055/open_spiel/abseil-cpp/absl/strings/internal/str_format/extension.h:375:3: error: default initialization of an object of const type 'const absl::FormatConversionCharSet'
#         ABSL_INTERNAL_CONVERSION_CHARS_EXPAND_(ABSL_INTERNAL_CHAR_SET_CASE, )
#         ^
#       /tmp/pip-install-of161ct7/open-spiel_54b6d96738814245809e552fe7edf055/open_spiel/abseil-cpp/absl/strings/internal/str_format/extension.h:161:9: note: expanded from macro 'ABSL_INTERNAL_CONVERSION_CHARS_EXPAND_'
#         X_VAL(c) X_SEP X_VAL(s) X_SEP \
#               ^
#       /tmp/pip-install-of161ct7/open-spiel_54b6d96738814245809e552fe7edf055/open_spiel/abseil-cpp/absl/strings/internal/str_format/extension.h:375:3: error: default initialization of an object of const type 'const absl::FormatConversionCharSet'
#       /tmp/pip-install-of161ct7/open-spiel_54b6d96738814245809e552fe7edf055/open_spiel/abseil-cpp/absl/strings/internal/str_format/extension.h:161:24: note: expanded from macro 'ABSL_INTERNAL_CONVERSION_CHARS_EXPAND_'
#         X_VAL(c) X_SEP X_VAL(s) X_SEP \
#                              ^
#       fatal error: too many errors emitted, stopping now [-ferror-limit=]
#       20 errors generated.
#       make[3]: *** [abseil-cpp/absl/strings/CMakeFiles/absl_str_format_internal.dir/build.make:104: abseil-cpp/absl/strings/CMakeFiles/absl_str_format_internal.dir/internal/str_format/extension.cc.o] Error 1
#       make[3]: *** Waiting for unfinished jobs....
#       [ 28%] Building CXX object abseil-cpp/absl/strings/CMakeFiles/absl_cord_internal.dir/internal/cord_rep_btree_reader.cc.o
#       [ 28%] Building CXX object abseil-cpp/absl/strings/CMakeFiles/absl_cord_internal.dir/internal/cord_rep_consume.cc.o
#       [ 30%] Linking CXX static library libabsl_random_distributions.a
#       [ 30%] Built target absl_random_distributions
#       [ 30%] Building CXX object abseil-cpp/absl/strings/CMakeFiles/absl_cord_internal.dir/internal/cord_rep_ring.cc.o
#       In file included from /tmp/pip-install-of161ct7/open-spiel_54b6d96738814245809e552fe7edf055/open_spiel/abseil-cpp/absl/strings/internal/str_format/float_conversion.cc:15:
#       In file included from /tmp/pip-install-of161ct7/open-spiel_54b6d96738814245809e552fe7edf055/open_spiel/abseil-cpp/absl/strings/internal/str_format/float_conversion.h:18:
#       /tmp/pip-install-of161ct7/open-spiel_54b6d96738814245809e552fe7edf055/open_spiel/abseil-cpp/absl/strings/internal/str_format/extension.h:34:35: error: unknown type name 'uint8_t'
#       enum class FormatConversionChar : uint8_t;
#                                         ^
#       /tmp/pip-install-of161ct7/open-spiel_54b6d96738814245809e552fe7edf055/open_spiel/abseil-cpp/absl/strings/internal/str_format/extension.h:35:38: error: unknown type name 'uint64_t'
#       enum class FormatConversionCharSet : uint64_t;
#                                            ^
#       /tmp/pip-install-of161ct7/open-spiel_54b6d96738814245809e552fe7edf055/open_spiel/abseil-cpp/absl/strings/internal/str_format/extension.h:131:20: error: unknown type name 'uint8_t'
#       enum class Flags : uint8_t {
#                          ^
#       /tmp/pip-install-of161ct7/open-spiel_54b6d96738814245809e552fe7edf055/open_spiel/abseil-cpp/absl/strings/internal/str_format/extension.h:144:41: error: unknown type name 'uint8_t'
#         return static_cast<Flags>(static_cast<uint8_t>(a) | static_cast<uint8_t>(b));
#                                               ^
#       /tmp/pip-install-of161ct7/open-spiel_54b6d96738814245809e552fe7edf055/open_spiel/abseil-cpp/absl/strings/internal/str_format/extension.h:144:67: error: unknown type name 'uint8_t'
#         return static_cast<Flags>(static_cast<uint8_t>(a) | static_cast<uint8_t>(b));
#                                                                         ^
#       /tmp/pip-install-of161ct7/open-spiel_54b6d96738814245809e552fe7edf055/open_spiel/abseil-cpp/absl/strings/internal/str_format/extension.h:148:23: error: unknown type name 'uint8_t'
#         return (static_cast<uint8_t>(haystack) & static_cast<uint8_t>(needle)) ==
#                             ^
#       /tmp/pip-install-of161ct7/open-spiel_54b6d96738814245809e552fe7edf055/open_spiel/abseil-cpp/absl/strings/internal/str_format/extension.h:148:56: error: unknown type name 'uint8_t'
#         return (static_cast<uint8_t>(haystack) & static_cast<uint8_t>(needle)) ==
#                                                              ^
#       /tmp/pip-install-of161ct7/open-spiel_54b6d96738814245809e552fe7edf055/open_spiel/abseil-cpp/absl/strings/internal/str_format/extension.h:148:42: error: invalid operands to binary expression ('absl::str_format_internal::Flags' and 'absl::str_format_internal::Flags')
#         return (static_cast<uint8_t>(haystack) & static_cast<uint8_t>(needle)) ==
#                                      ~~~~~~~~  ^                      ~~~~~~
#       /tmp/pip-install-of161ct7/open-spiel_54b6d96738814245809e552fe7edf055/open_spiel/abseil-cpp/absl/strings/internal/str_format/extension.h:149:22: error: unknown type name 'uint8_t'
#                static_cast<uint8_t>(needle);
#                            ^
#       /tmp/pip-install-of161ct7/open-spiel_54b6d96738814245809e552fe7edf055/open_spiel/abseil-cpp/absl/strings/internal/str_format/extension.h:187:21: error: unknown type name 'uint8_t'
#         enum class Enum : uint8_t {
#                           ^
#       /tmp/pip-install-of161ct7/open-spiel_54b6d96738814245809e552fe7edf055/open_spiel/abseil-cpp/absl/strings/internal/str_format/extension.h:345:19: error: unknown type name 'uint64_t'
#             static_cast<uint64_t>(a) |
#                         ^
#       /tmp/pip-install-of161ct7/open-spiel_54b6d96738814245809e552fe7edf055/open_spiel/abseil-cpp/absl/strings/internal/str_format/extension.h:346:19: error: unknown type name 'uint64_t'
#             static_cast<uint64_t>(FormatConversionCharSetUnion(rest...)));
#                         ^
#       /tmp/pip-install-of161ct7/open-spiel_54b6d96738814245809e552fe7edf055/open_spiel/abseil-cpp/absl/strings/internal/str_format/extension.h:349:11: error: unknown type name 'uint64_t'
#       constexpr uint64_t FormatConversionCharToConvInt(FormatConversionChar c) {
#                 ^
#       /tmp/pip-install-of161ct7/open-spiel_54b6d96738814245809e552fe7edf055/open_spiel/abseil-cpp/absl/strings/internal/str_format/extension.h:350:10: error: use of undeclared identifier 'uint64_t'
#         return uint64_t{1} << (1 + static_cast<uint8_t>(c));
#                ^
#       /tmp/pip-install-of161ct7/open-spiel_54b6d96738814245809e552fe7edf055/open_spiel/abseil-cpp/absl/strings/internal/str_format/extension.h:350:18: error: expected ';' after return statement
#         return uint64_t{1} << (1 + static_cast<uint8_t>(c));
#                        ^
#                        ;
#       /tmp/pip-install-of161ct7/open-spiel_54b6d96738814245809e552fe7edf055/open_spiel/abseil-cpp/absl/strings/internal/str_format/extension.h:353:11: error: unknown type name 'uint64_t'
#       constexpr uint64_t FormatConversionCharToConvInt(char conv) {
#                 ^
#       /tmp/pip-install-of161ct7/open-spiel_54b6d96738814245809e552fe7edf055/open_spiel/abseil-cpp/absl/strings/internal/str_format/extension.h:366:35: error: no return statement in constexpr function
#       constexpr FormatConversionCharSet FormatConversionCharToConvValue(char conv) {
#                                         ^
#       /tmp/pip-install-of161ct7/open-spiel_54b6d96738814245809e552fe7edf055/open_spiel/abseil-cpp/absl/strings/internal/str_format/extension.h:375:3: error: default initialization of an object of const type 'const absl::FormatConversionCharSet'
#         ABSL_INTERNAL_CONVERSION_CHARS_EXPAND_(ABSL_INTERNAL_CHAR_SET_CASE, )
#         ^
#       /tmp/pip-install-of161ct7/open-spiel_54b6d96738814245809e552fe7edf055/open_spiel/abseil-cpp/absl/strings/internal/str_format/extension.h:161:9: note: expanded from macro 'ABSL_INTERNAL_CONVERSION_CHARS_EXPAND_'
#         X_VAL(c) X_SEP X_VAL(s) X_SEP \
#               ^
#       /tmp/pip-install-of161ct7/open-spiel_54b6d96738814245809e552fe7edf055/open_spiel/abseil-cpp/absl/strings/internal/str_format/extension.h:375:3: error: default initialization of an object of const type 'const absl::FormatConversionCharSet'
#       /tmp/pip-install-of161ct7/open-spiel_54b6d96738814245809e552fe7edf055/open_spiel/abseil-cpp/absl/strings/internal/str_format/extension.h:161:24: note: expanded from macro 'ABSL_INTERNAL_CONVERSION_CHARS_EXPAND_'
#         X_VAL(c) X_SEP X_VAL(s) X_SEP \
#                              ^
#       fatal error: too many errors emitted, stopping now [-ferror-limit=]
#       20 errors generated.
#       make[3]: *** [abseil-cpp/absl/strings/CMakeFiles/absl_str_format_internal.dir/build.make:118: abseil-cpp/absl/strings/CMakeFiles/absl_str_format_internal.dir/internal/str_format/float_conversion.cc.o] Error 1
#       [ 30%] Building CXX object abseil-cpp/absl/time/CMakeFiles/absl_time.dir/duration.cc.o
#       [ 30%] Building CXX object abseil-cpp/absl/time/CMakeFiles/absl_time.dir/format.cc.o
#       [ 30%] Building CXX object abseil-cpp/absl/time/CMakeFiles/absl_time.dir/time.cc.o
#       make[2]: *** [CMakeFiles/Makefile2:2973: abseil-cpp/absl/strings/CMakeFiles/absl_str_format_internal.dir/all] Error 2
#       make[2]: *** Waiting for unfinished jobs....
#       [ 32%] Linking CXX static library libabsl_time.a
#       [ 32%] Built target absl_time
#       [ 33%] Linking CXX static library libabsl_cord_internal.a
#       [ 33%] Built target absl_cord_internal
#       make[1]: *** [CMakeFiles/Makefile2:15091: python/CMakeFiles/pyspiel.dir/rule] Error 2
#       make: *** [Makefile:2734: pyspiel] Error 2
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "/tmp/pip-install-of161ct7/open-spiel_54b6d96738814245809e552fe7edf055/setup.py", line 130, in <module>
#           setuptools.setup(
#         File "/usr/lib/python3.11/site-packages/setuptools/__init__.py", line 107, in setup
#           return distutils.core.setup(**attrs)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/usr/lib/python3.11/site-packages/setuptools/_distutils/core.py", line 185, in setup
#           return run_commands(dist)
#                  ^^^^^^^^^^^^^^^^^^
#         File "/usr/lib/python3.11/site-packages/setuptools/_distutils/core.py", line 201, in run_commands
#           dist.run_commands()
#         File "/usr/lib/python3.11/site-packages/setuptools/_distutils/dist.py", line 969, in run_commands
#           self.run_command(cmd)
#         File "/usr/lib/python3.11/site-packages/setuptools/dist.py", line 1243, in run_command
#           super().run_command(command)
#         File "/usr/lib/python3.11/site-packages/setuptools/_distutils/dist.py", line 988, in run_command
#           cmd_obj.run()
#         File "/usr/lib/python3.11/site-packages/wheel/bdist_wheel.py", line 343, in run
#           self.run_command("build")
#         File "/usr/lib/python3.11/site-packages/setuptools/_distutils/cmd.py", line 318, in run_command
#           self.distribution.run_command(command)
#         File "/usr/lib/python3.11/site-packages/setuptools/dist.py", line 1243, in run_command
#           super().run_command(command)
#         File "/usr/lib/python3.11/site-packages/setuptools/_distutils/dist.py", line 988, in run_command
#           cmd_obj.run()
#         File "/usr/lib/python3.11/site-packages/setuptools/_distutils/command/build.py", line 131, in run
#           self.run_command(cmd_name)
#         File "/usr/lib/python3.11/site-packages/setuptools/_distutils/cmd.py", line 318, in run_command
#           self.distribution.run_command(command)
#         File "/usr/lib/python3.11/site-packages/setuptools/dist.py", line 1243, in run_command
#           super().run_command(command)
#         File "/usr/lib/python3.11/site-packages/setuptools/_distutils/dist.py", line 988, in run_command
#           cmd_obj.run()
#         File "/tmp/pip-install-of161ct7/open-spiel_54b6d96738814245809e552fe7edf055/setup.py", line 49, in run
#           self.build_extension(ext)
#         File "/tmp/pip-install-of161ct7/open-spiel_54b6d96738814245809e552fe7edf055/setup.py", line 100, in build_extension
#           subprocess.check_call(["make", "pyspiel", f"-j{os.cpu_count()}"],
#         File "/usr/lib/python3.11/subprocess.py", line 413, in check_call
#           raise CalledProcessError(retcode, cmd)
#       subprocess.CalledProcessError: Command '['make', 'pyspiel', '-j8']' returned non-zero exit status 2.
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for open_spiel
#   Running setup.py clean for open_spiel
# Failed to build open_spiel
# ERROR: Could not build wheels for open_spiel, which is required to install pyproject.toml-based projects
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 14
#      11 import itertools
#      13 import numpy as np
# ---> 14 import pyspiel
#      15 import tqdm
#      16 import copy
#
# ModuleNotFoundError: No module named 'pyspiel'

# %% [markdown]
# ## Monte Carlo Tree Search
#
# **Question:** Explain the main idea of MCTS.

# %% [markdown]
# ### MCTS loop

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <img align="center" width="400" src="data:image/png;base64,...">

# %% [markdown]
# $$ Q(s, a) + c * \sqrt{ \frac{\ln n_s}{n_{s,a}}} $$
#
# That is, keep:
#  - average values
#  - number of times a node was accessed
#
# Hint: you have the total number of the corresponding branch in the parent node.

# %% [markdown]
# **Question:**
# Consider UCT algorithm with exploration constant **c = 2**; assume that we **break ties** between actions **in favor of the left one** and **random rollout**. What part of the game tree will be built after 5 iterations of UCT algorithm. (perform on the whiteboard)

# %% [markdown]
# ### MCTS algorithm
#
# Let's create stateful bandits -- this is essentially the same thing we did in previous labs.

# %%
# We need to distinguish between _actions_ and _action_indices_ !!
Action = int

class Bandit:
    def total_visits(self) -> int:
        raise NotImplementedError()
    def select(self) -> Action:
        raise NotImplementedError()
    def update(self, value: float) -> None:
        self.visits[self.last_idx] += 1
        self.qs[self.last_idx] += (value - self.qs[self.last_idx]) \
                                  / self.visits[self.last_idx]
    def best_action(self) -> Action:
        raise NotImplementedError()
        

class EpsGreedyBandit(Bandit):
    def __init__(self, state: pyspiel.State, epsilon: float):
        self.epsilon = epsilon
        self.actions = state.legal_actions()
        self.qs = np.zeros(len(self.actions))
        self.visits = np.zeros(len(self.actions))
        self.last_idx = None

    def select(self) -> Action:
        if np.random.rand() < self.epsilon:
            self.last_idx = np.random.randint(len(self.actions))
        else:
            self.last_idx = np.argmax(self.qs)
            
        return self.actions[self.last_idx]

    def best_action(self) -> Action:
        return self.actions[np.argmax(self.qs)]


class UcbBandit(Bandit):
    def __init__(self, state: pyspiel.State, c_uct):
        self.c_uct = c_uct
        self.actions = state.legal_actions()
        self.qs = np.zeros(len(self.actions))
        self.visits = np.zeros(len(self.actions))  
        self.last_idx = None

    def total_visits(self) -> int:
        return np.sum(self.visits)

    def select(self) -> Action:
        total_visits = self.total_visits()
        ucb_vals = (
            self.qs + self.c_uct * np.sqrt(np.log(total_visits)/self.visits)
        )
        self.last_idx = np.argmax(ucb_vals)

        return self.actions[self.last_idx]

    def best_action(self) -> Action:
        return self.actions[np.argmax(self.qs)]

# %% [markdown]
# Let's implement MCTS.

# %% [markdown]
# **Question**: How to represent the search tree?

# %%
Trace = List[pyspiel.State]

def random_simulation(state: pyspiel.State) -> List[float]:
    while not state.is_terminal():
        random_action = np.random.choice(state.legal_actions())
        state.apply_action(random_action)
  
    return state.returns()

def node_depth(node: str) -> int:
  if node == "": 
    return 0
  else:
    return int((len(node) - 1) / 3 + 1)

class MCTS:
    def __init__(self, bandit_factory: Callable[[pyspiel.State], Bandit], 
                       simulate: Callable[[pyspiel.State], List[float]]):
        self.node_table: Dict[str, Bandit] = dict()
        self.bandit_factory = bandit_factory
        self.simulate = simulate

    def has_node(self, state: pyspiel.State) -> bool:
        return state.history_str() in self.node_table

    def get_node(self, state: pyspiel.State) -> Bandit:
        return self.node_table[state.history_str()]

    def make_node(self, state: pyspiel.State):
        self.node_table[state.history_str()] = self.bandit_factory(state)

    def deepest_node(self) -> int:
        return max(node_depth(node) for node in self.node_table.keys())

    def node_stats(self) -> Dict[int, int]:
      # Count the number of visited nodes at each depth. 
      nodes = sorted(self.node_table.keys())
      node_stats = defaultdict(int)

      for node in nodes:
        node_stats[node_depth(node)] += 1
      
      return node_stats

    def best_action(self, state: pyspiel.State) -> Action:
        return self.get_node(state).best_action()

    def step(self, state: pyspiel.State):
      # An invariant we rely on: there is always a bandit available 
      # for the current state to search from.
      if not self.has_node(state):
          self.make_node(state)

      # Therefore, there is always a trace:
      trace, last_state = self.select(state.clone())

      # Compute values, either by asking the game, or by making a simulation.
      if last_state.is_terminal():
          values = last_state.returns()
      else:
          self.expand(last_state)
          values = self.simulate(last_state.clone())

      # Backpropagate the values to make bandit updates along the trace,
      # except for the last node on the trace -- the leaf or the terminal.
      self.backpropagate(trace, values)

    def select(self, state: pyspiel.State) -> Tuple[Trace, pyspiel.State]:
        trace = [] # <- push state.clone() here

        while self.has_node(state):
          if state.is_terminal():
            break

          trace.append(state.clone())
          bandit = self.get_node(state)
          action = bandit.select()
          state.apply_action(action)
        
        return trace, state.clone() # trace & last_state

    def expand(self, state: pyspiel.State) -> None:
        self.make_node(state)

    def backpropagate(self, trace: Trace, values: List[float]) -> None:
        for state in reversed(trace):
          self.get_node(state).update(values[state.current_player()])

# %% [markdown]
# ## MCTS analysis
#
# We will be evaluating MCTS on the game of [connect four](https://en.wikipedia.org/wiki/Connect_Four).

# %% [markdown]
# ![](https://upload.wikimedia.org/wikipedia/commons/a/ad/Connect_Four.gif)

# %%
game = pyspiel.load_game("connect_four")
state = game.new_initial_state()
for i in range(8):
  state.apply_action(np.random.choice(state.legal_actions()))
state
# Out:
# .......
# .......
# .......
# ...x...
# ...x..o
# .xoox.o

# %% [markdown]
# **Question**: What is your intuition: what is the game value and where should the first player play?

# %% [markdown]
# **Question**: What is the deepest node in C4?

# %%
# Run & Skip

# Helper functions to record statistics
def record_mcts_stats(mcts: MCTS) -> None:
  game = pyspiel.load_game("connect_four")
  state = game.new_initial_state()

  stats = []
  for i in tqdm.tqdm(range(num_steps)):
    mcts.step(state)
    if i % record_step == 0:
      root_node = mcts.get_node(state)
      stats.append(dict(
          deepest_node=mcts.deepest_node(),
          qs=copy.copy(root_node.qs),
          visits=copy.copy(root_node.visits),
          best_action=root_node.best_action(),
          node_stats=mcts.node_stats()
      ))
  return stats

# Functions for plotting statistics
import matplotlib.pyplot as plt

y_labels = {
    "deepest_node" : "Largest depth",
    "qs" : "Q-values | Q(s,a)",
    "visits" : "Action tries | N(s, a)",
    "best_action" : "Best action"
}

def plot_stats(stats, to_plot=["deepest_node", "visits", "qs", "best_action"], title=''):
  fig, axes = plt.subplots(nrows=len(to_plot), ncols=1, squeeze=False, sharex=True, figsize=(13,5 * len(to_plot)))

  i = 0
    
  if title != '':
      axes[0, 0].set_title(title)
    
  for stat in to_plot:
      axes[i, 0].set_ylabel(y_labels[stat])
      axes[i, 0].set_xlabel("steps")
      axes[i, 0].plot(range(0, num_steps, record_step), [rec[stat] for rec in stats])
      if stat == "best_action":
            axes[i, 0].set_ylim([0, 6])
      axes[i, 0].tick_params(labelbottom=True)
      
      if len(axes[i, 0].lines) > 1:
        act = 0
        for line in axes[i, 0].lines:
            line.set_label("Action " + str(act))
            act += 1
        axes[i, 0].legend()
      i += 1

def plot_depth_histogram(stats, indices, record_step, title=""):
  fig, axes = plt.subplots(nrows=1, ncols=len(indices), 
                           squeeze=False, figsize=(6*len(indices),4))
  for i, idx in enumerate(indices):
    ax = axes[0][i]
    data = stats[idx]["node_stats"]
    # dicts can have wrong order... make into sorted tuples
    data = [(k,v) for k, v in data.items()]
    data = sorted(data, key=lambda kv: kv[0])
    sorted_keys = [k for k,v in data]
    sorted_values = [v for k,v in data]
    ax.set_title(f"After {idx*record_step} steps")
    ax.bar(range(len(data)), sorted_values, tick_label=sorted_keys)
    ax.set_xlabel("Depth")
    ax.set_ylabel("Visited nodes")
    
  if title != "":
    fig.suptitle(title, fontsize=16)

# %% [markdown]
# Let's run MCTS with $\epsilon$-greedy/UCB bandits and random simulations.
#
# While gradually increasing the number of steps, we will show:
# - the largest depth the algorithm reaches
# - Q-values and the number of tries for each action in the root node
# - the best action to take in the root node
# - depth histograms

# %% [markdown]
# **Question** To understand the following graphs, let's think about what is the possible range of: largest depth / Q values / visit counts / best action?

# %%
 num_steps = 10000
 record_step = 100

# %%
# MCTS with epsilon-greedy bandit

np.random.seed(111111)
mcts = MCTS(lambda state: EpsGreedyBandit(state, epsilon=0.2), random_simulation)
statsEGB = record_mcts_stats(mcts)
plot_stats(statsEGB)
plot_depth_histogram(statsEGB, [1, 10, 50, 99], record_step=record_step)
# Out:
# 100%|██████████| 10000/10000 [00:08<00:00, 1144.03it/s]

# %%
# MCTS with UCB bandit

np.random.seed(111111)
mcts = MCTS(lambda state: UcbBandit(state, c_uct=2), random_simulation)
statsUCT = record_mcts_stats(mcts)
plot_stats(statsUCT)
plot_depth_histogram(statsUCT, [1, 10, 50, 99], record_step=record_step)
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]<ipython-input-2-476206e58dd8>:51: RuntimeWarning: divide by zero encountered in log
#   self.qs + self.c_uct * np.sqrt(np.log(total_visits)/self.visits)
# <ipython-input-2-476206e58dd8>:51: RuntimeWarning: invalid value encountered in sqrt
#   self.qs + self.c_uct * np.sqrt(np.log(total_visits)/self.visits)
# <ipython-input-2-476206e58dd8>:51: RuntimeWarning: invalid value encountered in true_divide
#   self.qs + self.c_uct * np.sqrt(np.log(total_visits)/self.visits)
# <ipython-input-2-476206e58dd8>:51: RuntimeWarning: divide by zero encountered in true_divide
#   self.qs + self.c_uct * np.sqrt(np.log(total_visits)/self.visits)
# 100%|██████████| 10000/10000 [00:07<00:00, 1345.65it/s]

# %% [markdown]
# **Question** Note the visit counts for UCT "takes off" after some number of steps (plot 2). Can you explain this behaviour? (see plot **below**)

# %%
# Just plot "visits" stats from previously recorded stats for UCT
plot_stats(statsUCT, to_plot=['visits'])

# %% [markdown]
# **Question** Compare the depth and Q-values evolution of UCT and MCTS with `EpsGreedyBandit`. (see plots **below**)

# %%
# Just plot "deepest node" stats from previously recorded stats
plot_stats(statsEGB, ["deepest_node"], "MCTS + EpsGreedyBandit")
plot_stats(statsUCT, ["deepest_node"], "UCT")

# %%
# Just plot "Q-values" stats from previously recorded stats
plot_stats(statsEGB, ["qs"], "MCTS + EpsGreedyBandit")
plot_stats(statsUCT, ["qs"], "UCT")

# %% [markdown]
# **Question:** What should we do to reach deeper levels of the game tree when using MCTS with `EpsGreedyBandit`?

# %%
np.random.seed(111111)
mcts = MCTS(lambda state: EpsGreedyBandit(state, epsilon=0.2), random_simulation)
stats = record_mcts_stats(mcts)
plot_stats(stats, to_plot=["deepest_node"], title=r'$\epsilon = 0.2$')

np.random.seed(111111)
mcts = MCTS(lambda state: EpsGreedyBandit(state, epsilon=0.1), random_simulation)
stats = record_mcts_stats(mcts)
plot_stats(stats, to_plot=["deepest_node"], title=r'$\epsilon = 0.1$')
# Out:
# 100%|██████████| 10000/10000 [00:03<00:00, 2909.77it/s]
# 100%|██████████| 10000/10000 [00:04<00:00, 2257.26it/s]

# %% [markdown]
# **Question:** What should we do to do more exploring when using MCTS with `UcbBandit`?

# %%
np.random.seed(111111)
mcts = MCTS(lambda state: UcbBandit(state, c_uct=2), random_simulation)
stats = record_mcts_stats(mcts)
plot_depth_histogram(stats, [1, 10, 50, 99], record_step=record_step, title=r'$c = 2$')

np.random.seed(111111)
mcts = MCTS(lambda state: UcbBandit(state, c_uct=4), random_simulation)
stats = record_mcts_stats(mcts)
plot_depth_histogram(stats, [1, 10, 50, 99], record_step=record_step, title=r'$c = 4$')
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]<ipython-input-2-476206e58dd8>:51: RuntimeWarning: divide by zero encountered in log
#   self.qs + self.c_uct * np.sqrt(np.log(total_visits)/self.visits)
# <ipython-input-2-476206e58dd8>:51: RuntimeWarning: invalid value encountered in sqrt
#   self.qs + self.c_uct * np.sqrt(np.log(total_visits)/self.visits)
# <ipython-input-2-476206e58dd8>:51: RuntimeWarning: invalid value encountered in true_divide
#   self.qs + self.c_uct * np.sqrt(np.log(total_visits)/self.visits)
# <ipython-input-2-476206e58dd8>:51: RuntimeWarning: divide by zero encountered in true_divide
#   self.qs + self.c_uct * np.sqrt(np.log(total_visits)/self.visits)
# 100%|██████████| 10000/10000 [00:05<00:00, 1753.83it/s]
# 100%|██████████| 10000/10000 [00:05<00:00, 1785.49it/s]

# %% [markdown]
# ## MCTS and speed

# %% [markdown]
# **Question** How long does it take to perform 1000 samples in the root?

# %%
import time

mcts = MCTS(lambda state: UcbBandit(state, c_uct=2), random_simulation)
start = time.time_ns()
for i in range(1000):
    mcts.step(state)
duration = time.time_ns() - start
print("Performing 1000 samples took", duration / 1e9, "s")
# Out:
# <ipython-input-2-476206e58dd8>:51: RuntimeWarning: divide by zero encountered in log
#   self.qs + self.c_uct * np.sqrt(np.log(total_visits)/self.visits)
# <ipython-input-2-476206e58dd8>:51: RuntimeWarning: invalid value encountered in sqrt
#   self.qs + self.c_uct * np.sqrt(np.log(total_visits)/self.visits)
# <ipython-input-2-476206e58dd8>:51: RuntimeWarning: invalid value encountered in true_divide
#   self.qs + self.c_uct * np.sqrt(np.log(total_visits)/self.visits)
# <ipython-input-2-476206e58dd8>:51: RuntimeWarning: divide by zero encountered in true_divide
#   self.qs + self.c_uct * np.sqrt(np.log(total_visits)/self.visits)
# Performing 1000 samples took 0.468067759 s

# %% [markdown]
# **Question** How can we make the MCTS algorithm faster (in terms of time/sample)?
